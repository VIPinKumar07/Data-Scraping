# %% [markdown]
# ## Web Scraping
#
# #### Oneplus mobiles on flipkart
#
# Here, as mentioned in the assigned task, I chose flipkart (an e-commerce website) to scrap the data for mobiles of brand -  OnePlus

# %% [markdown]
# ### Required Libraries

# %%
import requests    # This module requests the page to get access for given URL and fetch the plain information from the page
from bs4 import BeautifulSoup           # Beautifulsoup is used to parse that information of HTML format and stored it
                                        # in more structure manner
from csv import writer
import pandas as pd

# %% [markdown]
# ### Web Scraping

# %%
products = []   # For storing the title of products
prices = []     # '' '' '' '' the price of products
storages = []   # '' '' '' '' the storage details of products
displays = []   # '' '' '' '' the display size of products
cameras = []    # '' '' '' '' the camera details of products
batteries = []  # '' '' '' '' the battery capacity of products

with open('OnePlus.csv', 'w', encoding='utf8', newline='') as f:
    thewriter = writer(f)
    header = ['Name', 'Price', 'Storage', 'Display', 'Camera', 'Battery'] # Headings for each categories
    thewriter.writerow(header)         # Writing header list as row in OnePlus.csv file
    
    for p in range(1,3):    # To get url of two pages
        url = "https://www.flipkart.com/mobiles/oneplus~brand/pr?sid=tyy%2C4io&page={}".format(p)
        
        page = requests.get(url)       # Requesting the page using url
        soup = BeautifulSoup(page.content, 'html.parser')   # Parsing the HTML page
        
        lists = soup.find_all('div', class_='_2kHMtA')   # All the sections on the page we are care about
        
        for lst in lists:
            title = lst.find('div', class_='_4rR01T').text  # Scraping title of the product
            products.append(title)
            
            price = lst.find('div', class_='_30jeq3 _1_WHN1').text  # Scraping price of the product
            prices.append(price)
            
            details = lst.find_all('li', class_='rgWa7D')   # Scraping details of the product
        
            # Storing the details in various categories
            storage = details[0].text.replace(' |',',')  
            storages.append(storage)
            
            display = details[1].text
            displays.append(display)
            
            camera = details[2].text.replace('|','Rear,')
            cameras.append(camera)
            
            battery = details[3].text
            batteries.append(battery)
        
            ind = title.find('(') # removing unneccesary info from the title of products
            
            # Storing all the info of a particular mobile in list
            info = [title[:ind-1], price, storage, display[0:8], camera[0:-7], battery[0:8]]
            thewriter.writerow(info)   # Writing info list as row in OnePlus.csv file
            print(info)
# Out:
# ['OnePlus Nord CE 2 Lite 5G', '₹19,969', '6 GB RAM, 128 GB ROM', '16.74 cm', '64MP Rear', '5000 mAh']
# ['OnePlus Nord CE 2 Lite 5G', '₹21,985', '8 GB RAM, 128 GB ROM', '16.74 cm', '64MP Rear', '5000 mAh']
# ['OnePlus Nord CE 2 Lite 5G', '₹21,989', '8 GB RAM, 128 GB ROM', '16.74 cm', '64MP Rear', '5000 mAh']
# ['OnePlus Nord 2 5G', '₹29,899', '8 GB RAM, 128 GB ROM', '16.33 cm', '50MP Rear', '4500 mAh']
# ['OnePlus Nord 2 5G', '₹33,999', '12 GB RAM, 256 GB ROM', '16.33 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 10R 5G', '₹38,990', '8 GB RAM, 128 GB ROM', '17.02 cm', '50MP Rear', '5000 mAh']
# ['OnePlus 9RT 5G', '₹44,984', '12 GB RAM, 256 GB ROM', '16.81 cm', '50MP Rear', '4500 mAh']
# ['OnePlus Nord CE 2 Lite 5G', '₹19,718', '6 GB RAM, 128 GB ROM', '16.74 cm', '64MP Rear', '5000 mAh']
# ['OnePlus 9RT 5G', '₹40,999', '8 GB RAM, 128 GB ROM', '16.81 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 9RT 5G', '₹44,999', '12 GB RAM, 256 GB ROM', '16.81 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹49,999', '8 GB RAM, 128 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 5G', '₹42,999', '12 GB RAM, 256 GB ROM', '16.81 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 8T 5G', '₹35,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 8T 5G', '₹36,490', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 8T 5G', '₹37,999', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹54,990', '12 GB RAM, 256 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9RT 5G', '₹40,980', '8 GB RAM, 128 GB ROM', '16.81 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 9 5G', '₹42,649', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 5G', '₹42,990', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 5G', '₹39,990', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 5G', '₹34,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro', '₹54,990', '8 GB RAM, 128 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹48,999', '8 GB RAM, 128 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹56,999', '12 GB RAM, 256 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹56,999', '12 GB RAM, 256 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro', '₹49,997', '8 GB RAM, 128 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹48,999', '8 GB RAM, 128 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9 Pro 5G', '₹56,999', '12 GB RAM, 256 GB ROM', '17.02 cm', '48MP Rear', '4500 mAh']
# ['OnePlus Nord CE 2 5G', '₹24,999', '8 GB RAM, 128 GB ROM', '16.33 cm', '64MP Rear', '4500 mAh']
# ['OnePlus Nord CE 2 5G', '₹23,999', '6 GB RAM, 128 GB ROM', '16.33 cm', '64MP Rear', '4500 mAh']
# ['OnePlus Nord 2 5G', '₹34,990', '12 GB RAM, 256 GB ROM', '16.33 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 10R 5G', '₹39,998', '12 GB RAM, 256 GB ROM', '17.02 cm', '50MP Rear', '5000 mAh']
# ['OnePlus Nord 2 5G', '₹34,999', '12 GB RAM, 256 GB ROM', '16.33 cm', '50MP Rear', '4500 mAh']
# ['OnePlus Nord CE 2 5G', '₹24,990', '8 GB RAM, 128 GB ROM', '16.33 cm', '64MP Rear', '4500 mAh']
# ['OnePlus 10R 5G', '₹43,999', '12 GB RAM, 256 GB ROM', '17.02 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 9R 5G', '₹33,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 10 Pro 5G', '₹69,990', '12 GB RAM, 256 GB ROM', '17.02 cm', '48MP Rear', '5000 mAh']
# ['OnePlus Nord CE 2 5G', '₹23,990', '6 GB RAM, 128 GB ROM', '16.33 cm', '64MP Rear', '4500 mAh']
# ['OnePlus 9R 5G', '₹37,999', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 8', '₹34,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP + 2MP + 16MP Rear, 16MP Front', '4300 mAh']
# ['OnePlus 7T Pro', '₹34,999', '8 GB RAM, 256 GB ROM', '16.94 cm', '48MP +8MP+16MP Rear, 16MP Dual Front', '4085 mAh']
# ['OnePlus Nord CE 5G', '₹27,999', '12 GB RAM, 256 GB ROM', '16.33 cm', '64MP Rear', '4500 mAh']
# ['OnePlus Nord 2 5G', '₹34,999', '12 GB RAM, 256 GB ROM', '16.33 cm', '50MP Rear', '4500 mAh']
# ['OnePlus 9R 5G', '₹38,999', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 9R 5G', '₹33,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP Rear', '4500 mAh']
# ['OnePlus 8', '₹34,999', '12 GB RAM, 256 GB ROM', '16.64 cm', '48MP + 2MP + 16MP Rear, 16MP Front', '4300 mAh']
# ['OnePlus 8', '₹44,999', '8 GB RAM, 128 GB ROM', '16.64 cm', '48MP + 2MP + 16MP Rear, 16MP Front', '4300 mAh']
# ['OnePlus 8', '₹41,999', '6 GB RAM, 128 GB ROM', '16.64 cm', '48MP', '4300 mAh']

# %% [markdown]
# ### Converting all the informations into a Dataframe

# %%
df = pd.DataFrame({'Product Name':products, 'Price':prices, 'Storage':storages, 'Display':displays,'Camera':cameras, 'Battery':batteries})

# %%
df
# Out:
#                                          Product Name    Price  \
# 0       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹19,969
# 1       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)  ₹21,985
# 2      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  ₹21,989
# 3             OnePlus Nord 2 5G (Gray Sierra, 128 GB)  ₹29,899
# 4                 OnePlus Nord 2 5G (PAC-MAN, 256 GB)  ₹33,999
# 5               OnePlus 10R 5G (Sierra Black, 128 GB)  ₹38,990
# 6               OnePlus 9RT 5G (Hacker Black, 256 GB)  ₹44,984
# 7      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)  ₹19,718
# 8                OnePlus 9RT 5G (Nano Silver, 128 GB)  ₹40,999
# 9                OnePlus 9RT 5G (Nano Silver, 256 GB)  ₹44,999
# 10            OnePlus 9 Pro 5G (Morning Mist, 128 GB)  ₹49,999
# 11                OnePlus 9 5G (Astral Black, 256 GB)  ₹42,999
# 12               OnePlus 8T 5G (Lunar Silver, 128 GB)  ₹35,999
# 13           OnePlus 8T 5G (Aquamarine Green, 128 GB)  ₹36,490
# 14               OnePlus 8T 5G (Lunar Silver, 256 GB)  ₹37,999
# 15              OnePlus 9 Pro 5G (Pine Green, 256 GB)  ₹54,990
# 16              OnePlus 9RT 5G (Hacker Black, 128 GB)  ₹40,980
# 17                 OnePlus 9 5G (Winter Mist, 256 GB)  ₹42,649
# 18                  OnePlus 9 5G (Arctic Sky, 256 GB)  ₹42,990
# 19                OnePlus 9 5G (Astral Black, 128 GB)  ₹39,990
# 20                  OnePlus 9 5G (Arctic Sky, 128 GB)  ₹34,999
# 21                 OnePlus 9 Pro (Pine Green, 128 GB)  ₹54,990
# 22           OnePlus 9 Pro 5G (Stellar Black, 128 GB)  ₹48,999
# 23            OnePlus 9 Pro 5G (Morning Mist, 256 GB)  ₹56,999
# 24           OnePlus 9 Pro 5G (Stellar Black, 256 GB)  ₹56,999
# 25                 OnePlus 9 Pro (Pine Green, 128 GB)  ₹49,997
# 26           OnePlus 9 Pro 5G (Stellar Black, 128 GB)  ₹48,999
# 27            OnePlus 9 Pro 5G (Morning Mist, 256 GB)  ₹56,999
# 28         OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)  ₹24,999
# 29         OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)  ₹23,999
# 30            OnePlus Nord 2 5G (Gray Sierra, 256 GB)  ₹34,990
# 31              OnePlus 10R 5G (Forest Green, 256 GB)  ₹39,998
# 32              OnePlus Nord 2 5G (Blue Haze, 256 GB)  ₹34,999
# 33         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)  ₹24,990
# 34  OnePlus 10R 5G (Sierra Black-150W Supervooc, 2...  ₹43,999
# 35               OnePlus 9R 5G (Carbon Black, 128 GB)  ₹33,999
# 36         OnePlus 10 Pro 5G (Volcanic Black, 256 GB)  ₹69,990
# 37         OnePlus Nord CE 2 5G (Gray Mirror, 128 GB)  ₹23,990
# 38               OnePlus 9R 5G (Carbon Black, 256 GB)  ₹37,999
# 39                  OnePlus 8 (Glacial Green, 128 GB)  ₹34,999
# 40                 OnePlus 7T Pro (Haze Blue, 256 GB)  ₹34,999
# 41             OnePlus Nord CE 5G (Blue Void, 256 GB)  ₹27,999
# 42             OnePlus Nord 2 5G (Green Wood, 256 GB)  ₹34,999
# 43                  OnePlus 9R 5G (Lake Blue, 256 GB)  ₹38,999
# 44                  OnePlus 9R 5G (Lake Blue, 128 GB)  ₹33,999
# 45                     OnePlus 8 (Onyx Black, 256 GB)  ₹34,999
# 46                     OnePlus 8 (Onyx Black, 128 GB)  ₹44,999
# 47                  OnePlus 8 (Glacial Green, 128 GB)  ₹41,999
#
#                   Storage                                Display  \
# 0    6 GB RAM, 128 GB ROM           16.74 cm (6.59 inch) Display
# 1    8 GB RAM, 128 GB ROM           16.74 cm (6.59 inch) Display
# 2    8 GB RAM, 128 GB ROM           16.74 cm (6.59 inch) Display
# 3    8 GB RAM, 128 GB ROM           16.33 cm (6.43 inch) Display
# 4   12 GB RAM, 256 GB ROM           16.33 cm (6.43 inch) Display
# 5    8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 6   12 GB RAM, 256 GB ROM           16.81 cm (6.62 inch) Display
# 7    6 GB RAM, 128 GB ROM           16.74 cm (6.59 inch) Display
# 8    8 GB RAM, 128 GB ROM           16.81 cm (6.62 inch) Display
# 9   12 GB RAM, 256 GB ROM           16.81 cm (6.62 inch) Display
# 10   8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 11  12 GB RAM, 256 GB ROM           16.81 cm (6.62 inch) Display
# 12   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 13   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 14  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 15  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 16   8 GB RAM, 128 GB ROM           16.81 cm (6.62 inch) Display
# 17  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 18  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 19   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 20   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 21   8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 22   8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 23  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 24  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 25   8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 26   8 GB RAM, 128 GB ROM            17.02 cm (6.7 inch) Display
# 27  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 28   8 GB RAM, 128 GB ROM           16.33 cm (6.43 inch) Display
# 29   6 GB RAM, 128 GB ROM           16.33 cm (6.43 inch) Display
# 30  12 GB RAM, 256 GB ROM           16.33 cm (6.43 inch) Display
# 31  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 32  12 GB RAM, 256 GB ROM           16.33 cm (6.43 inch) Display
# 33   8 GB RAM, 128 GB ROM           16.33 cm (6.43 inch) Display
# 34  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 35   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 36  12 GB RAM, 256 GB ROM            17.02 cm (6.7 inch) Display
# 37   6 GB RAM, 128 GB ROM           16.33 cm (6.43 inch) Display
# 38  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 39   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 40   8 GB RAM, 256 GB ROM  16.94 cm (6.67 inch) Quad HD+ Display
# 41  12 GB RAM, 256 GB ROM           16.33 cm (6.43 inch) Display
# 42  12 GB RAM, 256 GB ROM           16.33 cm (6.43 inch) Display
# 43  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 44   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 45  12 GB RAM, 256 GB ROM           16.64 cm (6.55 inch) Display
# 46   8 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
# 47   6 GB RAM, 128 GB ROM           16.64 cm (6.55 inch) Display
#
#                                          Camera           Battery
# 0                              64MP Rear Camera  5000 mAh Battery
# 1                              64MP Rear Camera  5000 mAh Battery
# 2                              64MP Rear Camera  5000 mAh Battery
# 3                              50MP Rear Camera  4500 mAh Battery
# 4                              50MP Rear Camera  4500 mAh Battery
# 5                              50MP Rear Camera  5000 mAh Battery
# 6                              50MP Rear Camera  4500 mAh Battery
# 7                              64MP Rear Camera  5000 mAh Battery
# 8                              50MP Rear Camera  4500 mAh Battery
# 9                              50MP Rear Camera  4500 mAh Battery
# 10                             48MP Rear Camera  4500 mAh Battery
# 11                             48MP Rear Camera  4500 mAh Battery
# 12                             48MP Rear Camera  4500 mAh Battery
# 13                             48MP Rear Camera  4500 mAh Battery
# 14                             48MP Rear Camera  4500 mAh Battery
# 15                             48MP Rear Camera  4500 mAh Battery
# 16                             50MP Rear Camera  4500 mAh Battery
# 17                             48MP Rear Camera  4500 mAh Battery
# 18                             48MP Rear Camera  4500 mAh Battery
# 19                             48MP Rear Camera  4500 mAh Battery
# 20                             48MP Rear Camera  4500 mAh Battery
# 21                             48MP Rear Camera  4500 mAh Battery
# 22                             48MP Rear Camera  4500 mAh Battery
# 23                             48MP Rear Camera  4500 mAh Battery
# 24                             48MP Rear Camera  4500 mAh Battery
# 25                             48MP Rear Camera  4500 mAh Battery
# 26                             48MP Rear Camera  4500 mAh Battery
# 27                             48MP Rear Camera  4500 mAh Battery
# 28                             64MP Rear Camera  4500 mAh Battery
# 29                             64MP Rear Camera  4500 mAh Battery
# 30                             50MP Rear Camera  4500 mAh Battery
# 31                             50MP Rear Camera  5000 mAh Battery
# 32                             50MP Rear Camera  4500 mAh Battery
# 33                             64MP Rear Camera  4500 mAh Battery
# 34                             50MP Rear Camera  4500 mAh Battery
# 35                             48MP Rear Camera  4500 mAh Battery
# 36                             48MP Rear Camera  5000 mAh Battery
# 37                             64MP Rear Camera  4500 mAh Battery
# 38                             48MP Rear Camera  4500 mAh Battery
# 39    48MP + 2MP + 16MP Rear, 16MP Front Camera  4300 mAh Battery
# 40  48MP +8MP+16MP Rear, 16MP Dual Front Camera  4085 mAh Battery
# 41                             64MP Rear Camera  4500 mAh Battery
# 42                             50MP Rear Camera  4500 mAh Battery
# 43                             48MP Rear Camera  4500 mAh Battery
# 44                             48MP Rear Camera  4500 mAh Battery
# 45    48MP + 2MP + 16MP Rear, 16MP Front Camera  4300 mAh Battery
# 46    48MP + 2MP + 16MP Rear, 16MP Front Camera  4300 mAh Battery
# 47                                  48MP + 16MP  4300 mAh Battery

# %%
info
# Out:
# ['OnePlus 8',
#  '₹41,999',
#  '6 GB RAM, 128 GB ROM',
#  '16.64 cm',
#  '48MP',
#  '4300 mAh']
